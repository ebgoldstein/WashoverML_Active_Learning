# %%
import os, shutil
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import matplotlib.image as mpimg

# %%
# #Florence
# #csv path
# newpredcsv = '../data/tables/FlorenceFourthLabels20180917a.csv'
# #raw image path:
# aerial_folder = '../data/pics/raw/Florence_20180917a_jpgs/'
# #gradcam1 path
# GC1path = '../data/pics/gradcam/Model2/FL_GCimages/'
# #gradcam 2 path
# GC2path = '../data/pics/gradcam/Model3/F_GCimages/'
# #new folder Path for images
# gradcam_image_pathY = '../data/pics/gradcam/Model3_YN/No_to_Yes/Florence/'
# gradcam_image_pathN = '../data/pics/gradcam/Model3_YN/Yes_to_No/Florence/'


# ##Michael
# newpredcsv = '../data/tables/MichaelFourthLabels20181011a.csv'
# aerial_folder = '../data/pics/raw/Michael_20181011a_jpgs/'
# GC1path = '../data/pics/gradcam/Model2/M_GCimages/'
# GC2path = '../data/pics/gradcam/Model3/M_GCimages/'
# gradcam_image_pathY = '../data/pics/gradcam/Model3_YN/No_to_Yes/Michael/'
# gradcam_image_pathN = '../data/pics/gradcam/Model3_YN/Yes_to_No/Michael/'

#Isaias
newpredcsv = '../data/tables/IsaiasFourthLabels20200804a.csv'
aerial_folder = '../data/pics/raw/Isaias_20200804a_jpgs/'
GC1path = '../data/pics/gradcam/Model2/I_GCimages/'
GC2path = '../data/pics/gradcam/Model3/I_GCimages/'
gradcam_image_pathY = '../data/pics/gradcam/Model3_YN/No_to_Yes/Isaias/'
gradcam_image_pathN = '../data/pics/gradcam/Model3_YN/Yes_to_No/Isaias/'

# %%
preds = pd.read_csv(newpredcsv)
preds.head()
# Out:
#    Unnamed: 0                               file storm_id         archive  \
# 0           0  20200804a_jpgs/jpgs/S21776978.jpg   isaias  20200804a_jpgs
# 1           1  20200804a_jpgs/jpgs/S21766393.jpg   isaias  20200804a_jpgs
# 2           2  20200804a_jpgs/jpgs/S21767012.jpg   isaias  20200804a_jpgs
# 3           3  20200804a_jpgs/jpgs/S21775298.jpg   isaias  20200804a_jpgs
# 4           4  20200804a_jpgs/jpgs/S21770086.jpg   isaias  20200804a_jpgs
#
#            image     size        date     lr_lon     ul_lat     ll_lat  ...  \
# 0  S21776978.jpg  6705271  2020/08/04 -79.889175  32.857442  32.854921  ...
# 1  S21766393.jpg  6259383  2020/08/04 -75.959077  35.095388  35.086077  ...
# 2  S21767012.jpg  6009380  2020/08/04 -76.294318  34.863638  34.853882  ...
# 3  S21775298.jpg  5281908  2020/08/04 -79.351721  33.014702  33.004522  ...
# 4  S21770086.jpg  7279868  2020/08/04 -77.485597  34.457228  34.446724  ...
#
#       ur_lon  prediction prediction2  washover  labeled  pred_certainty  \
# 0 -79.904018    0.006467    0.108500       NaN      NaN        0.493533
# 1 -75.966710    0.753434    0.969360       NaN      NaN        0.253434
# 2 -76.302168    0.786389    0.947221       NaN      NaN        0.286389
# 3 -79.353651    0.641310    0.437554       NaN      NaN        0.141310
# 4 -77.491345    0.701684    0.940632       NaN      NaN        0.201684
#
#    pred_certainty2  washImages  prediction3  pred_certainty3
# 0         0.391500    0.641500     0.282298         0.217702
# 1         0.469360    0.219360     0.999192         0.499192
# 2         0.447221    0.197221     0.999670         0.499670
# 3         0.062446    0.312446     0.999799         0.499799
# 4         0.440632    0.190632     0.999940         0.499940
#
# [5 rows x 25 columns]

# %%
# make a matrix based on model 1 and model 2

preds['Model_One_Wash'] = np.where(preds['prediction2'] > 0.5, True, False)
preds['Model_Two_Wash'] = np.where(preds['prediction3'] > 0.5, True, False)
preds.head()
# Out:
#    Unnamed: 0                               file storm_id         archive  \
# 0           0  20200804a_jpgs/jpgs/S21776978.jpg   isaias  20200804a_jpgs
# 1           1  20200804a_jpgs/jpgs/S21766393.jpg   isaias  20200804a_jpgs
# 2           2  20200804a_jpgs/jpgs/S21767012.jpg   isaias  20200804a_jpgs
# 3           3  20200804a_jpgs/jpgs/S21775298.jpg   isaias  20200804a_jpgs
# 4           4  20200804a_jpgs/jpgs/S21770086.jpg   isaias  20200804a_jpgs
#
#            image     size        date     lr_lon     ul_lat     ll_lat  ...  \
# 0  S21776978.jpg  6705271  2020/08/04 -79.889175  32.857442  32.854921  ...
# 1  S21766393.jpg  6259383  2020/08/04 -75.959077  35.095388  35.086077  ...
# 2  S21767012.jpg  6009380  2020/08/04 -76.294318  34.863638  34.853882  ...
# 3  S21775298.jpg  5281908  2020/08/04 -79.351721  33.014702  33.004522  ...
# 4  S21770086.jpg  7279868  2020/08/04 -77.485597  34.457228  34.446724  ...
#
#    prediction2  washover labeled  pred_certainty  pred_certainty2  washImages  \
# 0     0.108500       NaN     NaN        0.493533         0.391500    0.641500
# 1     0.969360       NaN     NaN        0.253434         0.469360    0.219360
# 2     0.947221       NaN     NaN        0.286389         0.447221    0.197221
# 3     0.437554       NaN     NaN        0.141310         0.062446    0.312446
# 4     0.940632       NaN     NaN        0.201684         0.440632    0.190632
#
#    prediction3  pred_certainty3  Model_One_Wash  Model_Two_Wash
# 0     0.282298         0.217702           False           False
# 1     0.999192         0.499192            True            True
# 2     0.999670         0.499670            True            True
# 3     0.999799         0.499799           False            True
# 4     0.999940         0.499940            True            True
#
# [5 rows x 27 columns]

# %%
#make a confuson matrix w/ crosstab
#For florence, 2062 are both false, 1208 are both true
#153 went from true to false
#218 went from false to true


confusion_matrix = pd.crosstab(preds['Model_One_Wash'], preds['Model_Two_Wash'], rownames=['Model 1'], colnames=['Model 2'])
print (confusion_matrix)
# Out:
# Model 2  False  True
# Model 1
# False     1100    239
# True       588   1555

# %%
#add the path
preds['Image_Path'] = aerial_folder + preds['image'].astype(str)
preds['GC1_Path'] = GC1path + preds['image'].astype(str)
preds['GC2_Path'] = GC2path + preds['image'].astype(str)
preds['Y_Path'] = gradcam_image_pathY + preds['image'].astype(str) + '.pdf'
preds['N_Path'] = gradcam_image_pathN + preds['image'].astype(str) +'.pdf'
#preds.head()

# %%
#select New Yes (false then true)
New_Yes_preds = preds[(preds.Model_One_Wash == False) & (preds.Model_Two_Wash == True)]

#New_Yes_preds

#select New No (true then false)
New_No_preds = preds[(preds.Model_One_Wash == True) & (preds.Model_Two_Wash == False)]

# %%
# plot image, GC1, GC2

# j = 1500

# plt.figure(figsize=(20,20))
# plt.subplot(131)
# plt.imshow(mpimg.imread(preds.Image_Path[j]))
# plt.title('Original Image')
# plt.subplot(132)
# plt.imshow(mpimg.imread(preds.GC1_Path[j]))
# plt.title('Model 1: {}'.format(preds.prediction[j]))
# plt.subplot(133)
# plt.imshow(mpimg.imread(preds.GC2_Path[j]))
# plt.title('Model 2: {}'.format(preds.prediction2[j]))


#plt.savefig('images/FPgrad_{}.pdf'.format(ip), format='pdf')

# %%
#do the new yes

#move those on the list
for index, row in New_Yes_preds.iterrows():
    #make figure
    plt.figure(figsize=(20,20))
    plt.subplot(131)
    plt.imshow(mpimg.imread(row['Image_Path']))
    plt.title('Original Image')
    plt.subplot(132)
    plt.imshow(mpimg.imread(row['GC1_Path']))
    plt.title('Model 2: {}'.format(row['prediction2']))
    plt.subplot(133)
    plt.imshow(mpimg.imread(row['GC2_Path']))
    plt.title('Model 3: {}'.format(row['prediction3']))

    #save figure
    plt.savefig(row['Y_Path'], format='pdf')
    plt.close()

# %%
#do the new no

#move those on the list
for index, row in New_No_preds.iterrows():
    #make figure
    plt.figure(figsize=(20,20))
    plt.subplot(131)
    plt.imshow(mpimg.imread(row['Image_Path']))
    plt.title('Original Image')
    plt.subplot(132)
    plt.imshow(mpimg.imread(row['GC1_Path']))
    plt.title('Model 2: {}'.format(row['prediction2']))
    plt.subplot(133)
    plt.imshow(mpimg.imread(row['GC2_Path']))
    plt.title('Model 3: {}'.format(row['prediction3']))

    #save figure
    plt.savefig(row['N_Path'], format='pdf')
    plt.close()
